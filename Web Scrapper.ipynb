# %%
import json
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

# Initialize WebDriver
driver = webdriver.Chrome()  # Ensure ChromeDriver is installed and compatible

# Navigate to the website's domain to set up the context
driver.get('https://app.airdna.co')  # Adjust URL to match the domain of the cookies

# Load cookies from the cookies.json file
with open('cookies.json', 'r') as cookiesfile:
    cookies = json.load(cookiesfile)

# Add each cookie to the Selenium browser session
for cookie in cookies:
    cookie.pop('sameSite', None)
    cookie.pop('storeId', None)
    cookie.pop('session', None)
    cookie.pop('hostOnly', None)
    cookie.pop('httpOnly', None)
    cookie.pop('path', None)
    cookie.pop('expirationDate', None)

    try:
        driver.add_cookie(cookie)
    except Exception as e:
        print(f"Could not add cookie {cookie['name']}: {e}")

# Refresh the page to apply the cookies
driver.refresh()
time.sleep(3)

# Navigate to the specific page
driver.get('https://www.airdna.co/vacation-rental-data/app/fr/ile-de-france')
time.sleep(3)

# Find all links that end with 'overview'
links = driver.find_elements(By.CSS_SELECTOR, "a")
overview_urls = [link.get_attribute('href') for link in links if link.get_attribute('href') and link.get_attribute('href').endswith("overview")]

data = []

# Loop through each overview URL
for url in overview_urls:
    try:
        driver.get(url)
        time.sleep(5)

        # Extract city name
        try:
            city_name = driver.find_element(By.XPATH, "//span[contains(@class, 'MuiBox-root') and text()]").text
        except:
            city_name = "N/A"

        # Extract market score
        try:
            market_score = driver.find_element(By.XPATH, "//h1[contains(@class, 'MuiTypography-titleXL')]").text
        except:
            market_score = "N/A"

        # Extract annual revenue
        try:
            annual_revenue = driver.find_element(By.XPATH, "//h6[text()='Annual Revenue']/following-sibling::div//h3").text
        except:
            annual_revenue = "N/A"

        # Extract occupancy rate
        try:
            occupancy_rate = driver.find_element(By.XPATH, "//h6[text()='Occupancy Rate']/following-sibling::div//h3").text
        except:
            occupancy_rate = "N/A"

        # Extract average daily rate
        try:
            avg_daily_rate = driver.find_element(By.XPATH, "//h6[text()='Average Daily Rate']/following-sibling::div//h3").text
        except:
            avg_daily_rate = "N/A"
        try:
            seasonality = driver.find_element(By.XPATH, "//p[contains(@class, 'MuiTypography-body2') and contains(text(), 'Seasonality')]/preceding-sibling::p").text
        except:
            seasonality = "N/A"

        # Append the data
        data.append({
            "City": city_name,
            "Market Score": market_score,
            "Annual Revenue": annual_revenue,
            "Occupancy Rate": occupancy_rate,
            "Average Daily Rate": avg_daily_rate
            "Seasonality" : seasonality
        })

        print(f"Data extracted for {city_name}")

    except Exception as e:
        print(f"Error processing URL {url}: {e}")

# Create a DataFrame
df = pd.DataFrame(data)
print(df)
# Save the DataFrame to a CSV file
df.to_csv('Final_file.csv', index=False)
print("Data saved to 'Final_file.csv'.")

# Close the browser
 driver.quit()
# Out:
# Data extracted for Ablis
# Data extracted for Ablon Sur Seine
# Data extracted for Acheres La Foret
# Data extracted for Acheres
# Data extracted for Aincourt
# Data extracted for Alfortville
# Data extracted for Andilly
# Data extracted for Andresy
# Data extracted for Angerville
# Data extracted for Annet Sur Marne
# Data extracted for Antony
# Data extracted for Arbonne La Foret
# Data extracted for Arcueil
# Data extracted for Argenteuil
# Data extracted for Arnouville Les Mantes
# Data extracted for Arnouville
# Data extracted for Arpajon
# Data extracted for Asnieres Sur Oise
# Data extracted for Asnieres Sur Seine
# Data extracted for Athis Mons
# Data extracted for Aubergenville
# Data extracted for Aubervilliers
# Data extracted for Auffargis
# Data extracted for Aulnay Sous Bois
# Data extracted for Aulnoy
# Data extracted for Auvers Sur Oise
# Data extracted for Avon
# Data extracted for Bagneaux Sur Loing
# Data extracted for Bagneux
# Data extracted for Bagnolet
# Data extracted for Baillet En France
# Data extracted for Bailly Romainvilliers
# Data extracted for Bailly
# Data extracted for Ballainvilliers
# Data extracted for Ballancourt Sur Essonne
# Data extracted for Barbizon
# Data extracted for Bazainville
# Data extracted for Beauchamp
# Data extracted for Beauchery Saint Martin
# Data extracted for Beaumont Sur Oise
# Data extracted for Bennecourt
# Data extracted for Bessancourt
# Data extracted for Beynes
# Data extracted for Bezons
# Data extracted for Bievres
# Data extracted for Bobigny
# Data extracted for Bois Colombes
# Data extracted for Bois D Arcy
# Data extracted for Bois Le Roi
# Data extracted for Boissise Le Roi
# Data extracted for Boissy Le Chatel
# Data extracted for Boissy Saint Leger
# Data extracted for Boissy Sans Avoir
# Data extracted for Boissy Sous Saint Yon
# Data extracted for Bondoufle
# Data extracted for Bondy
# Data extracted for Bonnelles
# Data extracted for Bonneuil En France
# Data extracted for Bonneuil Sur Marne
# Data extracted for Bonnieres Sur Seine
# Data extracted for Bouafle
# Data extracted for Bouffemont
# Data extracted for Bougival
# Data extracted for Bouleurs
# Data extracted for Boulogne Billancourt
# Data extracted for Bourdonne
# Data extracted for Bourg La Reine
# Data extracted for Bourron Marlotte
# Data extracted for Boussy Saint Antoine
# Data extracted for Boutigny Sur Essonne
# Data extracted for Bransles
# Data extracted for Bray Sur Seine
# Data extracted for Bretigny Sur Orge
# Data extracted for Breuillet
# Data extracted for Brie Comte Robert
# Data extracted for Briis Sous Forges
# Data extracted for Brou Sur Chantereine
# Data extracted for Brunoy
# Data extracted for Bruyeres Sur Oise
# Data extracted for Bry Sur Marne
# Data extracted for Buc
# Data extracted for Bullion
# Data extracted for Bures Sur Yvette
# Data extracted for Bussy Saint Georges
# Data extracted for Bussy Saint Martin
# Data extracted for Buthiers
# Data extracted for Cachan
# Data extracted for Carrieres Sous Poissy
# Data extracted for Carrieres Sur Seine
# Data extracted for Cergy
# Data extracted for Cerny
# Data extracted for Cesson
# Data extracted for Chailly En Biere
# Data extracted for Chaintreaux
# Data extracted for Chalifert
# Data extracted for Chalo Saint Mars
# Data extracted for Chambly
# Data extracted for Chambourcy
# Data extracted for Champagne Sur Oise
# Data extracted for Champagne Sur Seine
# Data extracted for Champcueil
# Data extracted for Champigny Sur Marne
# Data extracted for Champlan
# Data extracted for Champs Sur Marne
# Data extracted for Chanteloup En Brie
# Data extracted for Chanteloup Les Vignes
# Data extracted for Charenton Le Pont
# Data extracted for Chartrettes
# Data extracted for Chateau Landon
# Data extracted for Chateaufort
# Data extracted for Chatenay Malabry
# Data extracted for Chatillon La Borde
# Data extracted for Chatillon
# Data extracted for Chatou
# Data extracted for Chatres
# Data extracted for Chauconin Neufmontiers
# Data extracted for Chaumes En Brie
# Data extracted for Chavenay
# Data extracted for Chaville
# Data extracted for Chelles
# Data extracted for Chennevieres Sur Marne
# Data extracted for Chenou
# Data extracted for Chessy
# Data extracted for Chevilly Larue
# Data extracted for Chevrainvilliers
# Data extracted for Chevreuse
# Data extracted for N/A
# Data extracted for Chilly Mazarin
# Data extracted for Choisy Le Roi
# Data extracted for Clairefontaine En Yvelines
# Data extracted for Clamart
# Data extracted for Claye Souilly
# Data extracted for Clichy Sous Bois
# Data extracted for Clichy
# Data extracted for Coignieres
# Data extracted for Collegien
# Data extracted for Colombes
# Data extracted for Combs La Ville
# Data extracted for Conches Sur Gondoire
# Data extracted for Conde Sainte Libiaire
# Data extracted for Conflans Sainte Honorine
# Data extracted for Corbeil Essonnes
# Data extracted for Cormeilles En Parisis
# Data extracted for Coubron
# Data extracted for Couilly Pont Aux Dames
# Data extracted for Coulommiers
# Data extracted for Coupvray
# Data extracted for Courbevoie
# Data extracted for Courcouronnes
# Data extracted for Courdimanche
# Data extracted for Courgent
# Data extracted for Courtry
# Data extracted for Coutevroult
# Data extracted for Crecy La Chapelle
# Data extracted for Crespieres
# Data extracted for Creteil
# Data extracted for Croissy Beaubourg
# Data extracted for Croissy Sur Seine
# Data extracted for Crosne
# Data extracted for Dammarie Les Lys
# Data extracted for Dammartin En Goele
# Data extracted for Dammartin Sur Tigeaux
# Data extracted for Dampierre En Yvelines
# Data extracted for Dampmart
# Data extracted for Dannemois
# Data extracted for Deuil La Barre
# Data extracted for Domont
# Data extracted for Dormelles
# Data extracted for Dourdan
# Data extracted for Drancy
# Data extracted for Draveil
# Data extracted for Dugny
# Data extracted for Eaubonne
# Data extracted for Ecouen
# Data extracted for Ecquevilly
# Data extracted for Egly
# Data extracted for Elancourt
# Data extracted for Emerainville
# Data extracted for Enghien Les Bains
# Data extracted for Ennery
# Data extracted for Epinay Sous Senart
# Data extracted for Epinay Sur Orge
# Data extracted for Epinay Sur Seine
# Data extracted for Episy
# Data extracted for Epone
# Data extracted for Eragny
# Data extracted for Ermont
# Data extracted for Esbly
# Data extracted for Etampes
# Data extracted for Etrechy
# Data extracted for Evecquemont
# Data extracted for Evry
# Data extracted for Ezanville
# Data extracted for Faremoutiers
# Data extracted for Favieres
# Data extracted for Fayence
# Data extracted for Ferolles Attilly
# Data extracted for Ferrieres En Brie
# Data extracted for Feucherolles
# Data extracted for Fleury En Biere
# Data extracted for Fleury Merogis
# Data extracted for Fontaine Le Port
# Data extracted for Fontainebleau
# Data extracted for Fontenay Aux Roses
# Data extracted for Fontenay Le Fleury
# Data extracted for Fontenay Saint Pere
# Data extracted for Fontenay Sous Bois
# Data extracted for Fontenay Tresigny
# Data extracted for Fosses
# Data extracted for Fourqueux
# Data extracted for Franconville
# Data extracted for Fresnes
# Data extracted for Gagny
# Data extracted for Galluis
# Data extracted for Gambais
# Data extracted for Garancieres
# Data extracted for Garches
# Data extracted for Gargenville
# Data extracted for Garges Les Gonesse
# Data extracted for Gennevilliers
# Data extracted for Gentilly
# Data extracted for Gif Sur Yvette
# Data extracted for Gometz La Ville
# Data extracted for Gometz Le Chatel
# Data extracted for Gommecourt
# Data extracted for Gonesse
# Data extracted for Gournay Sur Marne
# Data extracted for Goussainville
# Data extracted for Gouvernes
# Data extracted for Gravon
# Data extracted for Gretz Armainvilliers
# Data extracted for Grez Sur Loing
# Data extracted for Grigny
# Data extracted for Grisy Suisnes
# Data extracted for Groslay
# Data extracted for Grosrouvre
# Data extracted for Guerard
# Data extracted for Guermantes
# Data extracted for Guyancourt
# Data extracted for Hardricourt
# Data extracted for Hargeville
# Data extracted for Herblay
# Data extracted for Hericy
# Data extracted for Hermeray
# Data extracted for Houdan
# Data extracted for Houilles
# Data extracted for Igny
# Data extracted for Isles Les Villenoy
# Data extracted for Issy Les Moulineaux
# Data extracted for Itteville
# Data extracted for Ivry Sur Seine
# Data extracted for Janvry
# Data extracted for Joinville Le Pont
# Data extracted for Jossigny
# Data extracted for Jouarre
# Data extracted for Jouars Pontchartrain
# Data extracted for Jouy En Josas
# Data extracted for Jouy Le Moutier
# Data extracted for Jouy Sur Morin
# Data extracted for Juvisy Sur Orge
# Data extracted for Juziers
# Data extracted for L Etang La Ville
# Data extracted for L Hay Les Roses
# Data extracted for L Ile Saint Denis
# Data extracted for L Isle Adam
# Data extracted for La Boissiere Ecole
# Data extracted for La Celle Saint Cloud
# Data extracted for La Chapelle La Reine
# Data extracted for La Chapelle Moutils
# Data extracted for La Courneuve
# Data extracted for La Ferte Alais
# Data extracted for La Ferte Gaucher
# Data extracted for La Ferte Sous Jouarre
# Data extracted for La Frette Sur Seine
# Data extracted for La Garenne Colombes
# Data extracted for La Genevraye
# Data extracted for La Grande Paroisse
# Data extracted for La Houssaye En Brie
# Data extracted for La Queue En Brie
# Data extracted for La Roche Guyon
# Data extracted for La Rochette
# Data extracted for La Verriere
# Data extracted for La Ville Du Bois
# Data extracted for Lagny Sur Marne
# Data extracted for Larchant
# Data extracted for Lardy
# Data extracted for Le Blanc Mesnil
# Data extracted for Le Bourget
# Data extracted for Le Chatelet En Brie
# Data extracted for Le Chesnay
# Data extracted for Le Coudray Montceaux
# Data extracted for Le Kremlin Bicetre
# Data extracted for Le Mee Sur Seine
# Data extracted for Le Mesnil Amelot
# Data extracted for Le Mesnil Le Roi
# Data extracted for Le Mesnil Saint Denis
# Data extracted for Le Pecq
# Data extracted for Le Perray En Yvelines
# Data extracted for Le Perreux Sur Marne
# Data extracted for Le Pin
# Data extracted for Le Plessis Bouchard
# Data extracted for Le Plessis Luzarches
# Data extracted for Le Plessis Robinson
# Data extracted for Le Plessis Trevise
# Data extracted for Le Port Marly
# Data extracted for Le Pre Saint Gervais
# Data extracted for Le Raincy
# Data extracted for Le Thillay
# Data extracted for Le Val Saint Germain
# Data extracted for Le Vaudoue
# Data extracted for Le Vesinet
# Data extracted for Les Breviaires
# Data extracted for Les Clayes Sous Bois
# Data extracted for Les Essarts Le Roi
# Data extracted for Les Lilas
# Data extracted for Les Loges En Josas
# Data extracted for Les Molieres
# Data extracted for Les Mureaux
# Data extracted for Les Pavillons Sous Bois
# Data extracted for Les Ulis
# Data extracted for Lesches
# Data extracted for Lesigny
# Data extracted for Leuville Sur Orge
# Data extracted for Levallois Perret
# Data extracted for Levis Saint Nom
# Data extracted for Lieusaint
# Data extracted for Limay
# Data extracted for Limeil Brevannes
# Data extracted for Limetz Villez
# Data extracted for Limours
# Data extracted for Linas
# Data extracted for Lisses
# Data extracted for Livry Gargan
# Data extracted for Lizy Sur Ourcq
# Data extracted for Lognes
# Data extracted for Lommoye
# Data extracted for Longjumeau
# Data extracted for Longpont Sur Orge
# Data extracted for Louveciennes
# Data extracted for Louvres
# Data extracted for Luzarches
# Data extracted for Maffliers
# Data extracted for Magny En Vexin
# Data extracted for Magny Le Hongre
# Data extracted for Magny Les Hameaux
# Data extracted for Maisons Alfort
# Data extracted for Maisons Laffitte
# Data extracted for Maisse
# Data extracted for Malakoff
# Data extracted for Mandres Les Roses
# Data extracted for Mantes La Jolie
# Data extracted for Mantes La Ville
# Data extracted for Marcoussis
# Data extracted for Mareil Marly
# Data extracted for Mareil Sur Mauldre
# Data extracted for Mareuil Les Meaux
# Data extracted for Margency
# Data extracted for Marines
# Data extracted for Marles En Brie
# Data extracted for Marly La Ville
# Data extracted for Marly Le Roi
# Data extracted for Marnes La Coquette
# Data extracted for Marolles En Brie
# Data extracted for Marolles En Hurepoix
# Data extracted for Massy
# Data extracted for Maule
# Data extracted for Mauperthuis
# Data extracted for Maurecourt
# Data extracted for Maurepas
# Data extracted for Meaux
# Data extracted for Medan
# Data extracted for Melun
# Data extracted for Mennecy
# Data extracted for Mere
# Data extracted for Meriel
# Data extracted for Mery Sur Oise
# Data extracted for Messy
# Data extracted for Meudon
# Data extracted for Meulan En Yvelines
# Data extracted for Mezieres Sur Seine
# Data extracted for Mezy Sur Seine
# Data extracted for Milly La Foret
# Data extracted for Misy Sur Yonne
# Data extracted for Mitry Mory
# Data extracted for Moigny Sur Ecole
# Data extracted for Moisenay
# Data extracted for Moisson
# Data extracted for Moissy Cramayel
# Data extracted for Montcourt Fromonville
# Data extracted for Montereau Fault Yonne
# Data extracted for Montesson
# Data extracted for Montevrain
# Data extracted for Montfermeil
# Data extracted for Montfort L Amaury
# Data extracted for Montge En Goele
# Data extracted for Montgeron
# Data extracted for Montigny Le Bretonneux
# Data extracted for Montigny Les Cormeilles
# Data extracted for Montigny Sur Loing
# Data extracted for Montlhery
# Data extracted for Montlignon
# Data extracted for Montmagny
# Data extracted for Montmorency
# Data extracted for Montreuil
# Data extracted for Montrouge
# Data extracted for Montry
# Data extracted for Montsoult
# Data extracted for Morainvilliers
# Data extracted for Morangis
# Data extracted for Mormant
# Data extracted for Morsang Sur Orge
# Data extracted for Morsang Sur Seine
# Data extracted for Mortcerf
# Data extracted for Mouroux
# Data extracted for Moussy Le Neuf
# Data extracted for Moussy Le Vieux
# Data extracted for Nandy
# Data extracted for Nangis
# Data extracted for Nanterre
# Data extracted for Nanteuil Les Meaux
# Data extracted for Nargis
# Data extracted for Neauphle Le Chateau
# Data extracted for Nemours
# Data extracted for Nerville La Foret
# Data extracted for Neufmoutiers En Brie
# Data extracted for Neuilly Plaisance
# Data extracted for Neuilly Sur Marne
# Data extracted for Neuilly Sur Seine
# Data extracted for Neuville Sur Oise
# Data extracted for Nogent Sur Marne
# Data extracted for Noisiel
# Data extracted for Noisy Le Grand
# Data extracted for Noisy Le Roi
# Data extracted for Noisy Le Sec
# Data extracted for Noisy Sur Ecole
# Data extracted for Nozay
# Data extracted for Ocquerre
# Data extracted for Oncy Sur Ecole
# Data extracted for Orgerus
# Data extracted for Orgeval
# Data extracted for Orly
# Data extracted for Ormesson Sur Marne
# Data extracted for Ormoy La Riviere
# Data extracted for Orsay
# Data extracted for Orvanne
# Data extracted for Osny
# Data extracted for Othis
# Data extracted for Ozoir La Ferriere
# Data extracted for Palaiseau
# Data extracted for Paley
# Data extracted for Pantin
# Data extracted for Paray Vieille Poste
# Data extracted for Paris
# Data extracted for Parmain
# Data extracted for Perigny
# Data extracted for Persan
# Data extracted for Perthes
# Data extracted for Pierrefitte Sur Seine
# Data extracted for Pierrelaye
# Data extracted for Plaisir
# Data extracted for Poigny La Foret
# Data extracted for Poissy
# Data extracted for Poligny
# Data extracted for Pommeuse
# Data extracted for Pomponne
# Data extracted for Pontault Combault
# Data extracted for Pontcarre
# Data extracted for Pontoise
# Data extracted for Porcheville
# Data extracted for Presles En Brie
# Data extracted for Presles
# Data extracted for Provins
# Data extracted for Puiseux En France
# Data extracted for Puteaux
# Data extracted for Quincy Sous Senart
# Data extracted for Quincy Voisins
# Data extracted for Raizeux
# Data extracted for Rambouillet
# Data extracted for Recloses
# Data extracted for Ris Orangis
# Data extracted for Rochefort En Yvelines
# Data extracted for Rocquencourt
# Data extracted for Roissy En Brie
# Data extracted for Roissy En France
# Data extracted for Romainville
# Data extracted for Rosny Sous Bois
# Data extracted for Rosny Sur Seine
# Data extracted for Rueil Malmaison
# Data extracted for Rungis
# Data extracted for Saacy Sur Marne
# Data extracted for Saclay
# Data extracted for Saint Arnoult En Yvelines
# Data extracted for Saint Augustin
# Data extracted for Saint Brice Sous Foret
# Data extracted for Saint Cheron
# Data extracted for Saint Clair Sur Epte
# Data extracted for Saint Cloud
# Data extracted for Saint Cyr L Ecole
# Data extracted for Saint Cyr Sur Morin
# Data extracted for Saint Denis
# Data extracted for Saint Fargeau Ponthierry
# Data extracted for Saint Germain De La Grange
# Data extracted for Saint Germain En Laye
# Data extracted for Saint Germain Les Arpajon
# Data extracted for Saint Germain Les Corbeil
# Data extracted for Saint Germain Sur Morin
# Data extracted for Saint Gratien
# Data extracted for Saint Hilarion
# Data extracted for Saint Illiers La Ville
# Data extracted for Saint Jean Les Deux Jumeaux
# Data extracted for Saint Leu La Foret
# Data extracted for Saint Loup De Naud
# Data extracted for Saint Mammes
# Data extracted for Saint Mande
# Data extracted for Saint Mard
# Data extracted for Saint Martin En Biere
# Data extracted for Saint Martin La Garenne
# Data extracted for Saint Maur Des Fosses
# Data extracted for Saint Maurice
# Data extracted for Saint Michel Sur Orge
# Data extracted for Saint Nom La Breteche
# Data extracted for Saint Ouen L Aumone
# Data extracted for Saint Ouen
# Data extracted for Saint Pathus
# Data extracted for Saint Pierre Du Perray
# Data extracted for Saint Pierre Les Nemours
# Data extracted for Saint Prix
# Data extracted for Saint Remy L Honore
# Data extracted for Saint Remy Les Chevreuse
# Data extracted for Saint Sauveur Sur Ecole
# Data extracted for Saint Thibault Des Vignes
# Data extracted for Saint Witz
# Data extracted for Sainte Genevieve Des Bois
# Data extracted for Sainte Genevieve Les Gasny
# Data extracted for Saintry Sur Seine
# Data extracted for Saints
# Data extracted for Sammeron
# Data extracted for Samois Sur Seine
# Data extracted for Samoreau
# Data extracted for Sancy
# Data extracted for Sannois
# Data extracted for Santeny
# Data extracted for Sarcelles
# Data extracted for Sartrouville
# Data extracted for Saulx Les Chartreux
# Data extracted for Saulx Marchais
# Data extracted for Savigny Le Temple
# Data extracted for Savigny Sur Orge
# Data extracted for Sceaux
# Data extracted for Seine Port
# Data extracted for Septeuil
# Data extracted for Serris
# Data extracted for Sevran
# Data extracted for Sevres
# Data extracted for Soisy Sous Montmorency
# Data extracted for Soisy Sur Ecole
# Data extracted for Soisy Sur Seine
# Data extracted for Sonchamp
# Data extracted for Souppes Sur Loing
# Data extracted for Stains
# Data extracted for Sucy En Brie
# Data extracted for Suresnes
# Data extracted for Survilliers
# Data extracted for Taverny
# Data extracted for Thiais
# Data extracted for Thieux
# Data extracted for Thoiry
# Data extracted for Thomery
# Data extracted for Thorigny Sur Marne
# Data extracted for Thoury Ferottes
# Data extracted for Torcy
# Data extracted for Touquin
# Data extracted for Tournan En Brie
# Data extracted for Toussus Le Noble
# Data extracted for Trappes
# Data extracted for Tremblay En France
# Data extracted for Treuzy Levelay
# Data extracted for Triel Sur Seine
# Data extracted for Ury
# Data extracted for Vaires Sur Marne
# Data extracted for Valenton
# Data extracted for Vanves
# Data extracted for Varennes Jarcy
# Data extracted for Varennes Sur Seine
# Data extracted for Vaucresson
# Data extracted for Vauhallan
# Data extracted for Vaujours
# Data extracted for Vaureal
# Data extracted for Vaux Le Penil
# Data extracted for Vaux Sur Seine
# Data extracted for Velizy Villacoublay
# Data extracted for Vemars
# Data extracted for Veneux Les Sablons
# Data extracted for Verdelot
# Data extracted for Verneuil Sur Seine
# Data extracted for Vernon
# Data extracted for Vernou La Celle Sur Seine
# Data extracted for Vernouillet
# Data extracted for Verrieres Le Buisson
# Data extracted for Versailles
# Data extracted for Vert Le Grand
# Data extracted for Vert Le Petit
# Data extracted for Vert Saint Denis
# Data extracted for Vetheuil
# Data extracted for Viarmes
# Data extracted for Videlles
# Data extracted for Vigneux Sur Seine
# Data extracted for Villabe
# Data extracted for Ville D Avray
# Data extracted for Villebon Sur Yvette
# Data extracted for Villecerf
# Data extracted for Villeconin
# Data extracted for Villecresnes
# Data extracted for Villejuif
# Data extracted for Villejust
# Data extracted for Villemer
# Data extracted for Villemoisson Sur Orge
# Data extracted for Villemomble
# Data extracted for Villeneuve La Garenne
# Data extracted for Villeneuve Le Comte
# Data extracted for Villeneuve Le Roi
# Data extracted for Villeneuve Saint Denis
# Data extracted for Villeneuve Saint Georges
# Data extracted for Villeneuve Sous Dammartin
# Data extracted for Villeneuve Sur Bellot
# Data extracted for Villennes Sur Seine
# Data extracted for Villenoy
# Data extracted for Villeparisis
# Data extracted for Villepinte
# Data extracted for Villepreux
# Data extracted for Villeron
# Data extracted for Villetaneuse
# Data extracted for Villevaude
# Data extracted for Villiers Le Bacle
# Data extracted for Villiers Le Bel
# Data extracted for Villiers Saint Frederic
# Data extracted for Villiers Sous Grez
# Data extracted for Villiers Sur Marne
# Data extracted for Villiers Sur Morin
# Data extracted for Villiers Sur Orge
# Data extracted for Vincennes
# Data extracted for Viroflay
# Data extracted for Viry Chatillon
# Data extracted for Vitry Sur Seine
# Data extracted for Voisins Le Bretonneux
# Data extracted for Voulangis
# Data extracted for Voulx
# Data extracted for Vulaines Sur Seine
# Data extracted for Wissous
# Data extracted for Yerres
#                    City Market Score Annual Revenue Occupancy Rate  \
# 0                 Ablis            2          $6.2K            40%
# 1       Ablon Sur Seine           18          $3.1K            41%
# 2      Acheres La Foret           94         $31.9K            52%
# 3               Acheres           96          $5.2K            43%
# 4              Aincourt           19          $7.8K            29%
# ..                  ...          ...            ...            ...
# 645           Voulangis           84         $15.5K            50%
# 646               Voulx           74         $26.7K            44%
# 647  Vulaines Sur Seine            6          $8.8K            43%
# 648             Wissous           94          $7.4K            53%
# 649              Yerres           36            $6K            43%
#
#     Average Daily Rate
# 0                $82.1
# 1                $83.3
# 2               $312.7
# 3               $104.9
# 4               $289.6
# ..                 ...
# 645             $119.5
# 646             $289.8
# 647             $182.4
# 648             $179.7
# 649             $148.2
#
# [650 rows x 5 columns]

# %%
df.head()
# Out:
#                City Market Score Annual Revenue Occupancy Rate  \
# 0             Ablis            2          $6.2K            40%
# 1   Ablon Sur Seine           18          $3.1K            41%
# 2  Acheres La Foret           94         $31.9K            52%
# 3           Acheres           96          $5.2K            43%
# 4          Aincourt           19          $7.8K            29%
#
#   Average Daily Rate
# 0              $82.1
# 1              $83.3
# 2             $312.7
# 3             $104.9
# 4             $289.6

# %%
# Export the DataFrame to a CSV file
df.to_csv('airdna_data.csv', index=False)

print("Data exported to airdna_data.csv")
# Out:
# Data exported to airdna_data.csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   City                650 non-null    object
#  1   Market Score        650 non-null    object
#  2   Annual Revenue      650 non-null    object
#  3   Occupancy Rate      650 non-null    object
#  4   Average Daily Rate  650 non-null    object
# dtypes: object(5)
# memory usage: 25.5+ KB
